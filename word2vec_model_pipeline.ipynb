# %% [markdown]
# # About
#
# This notebook reads in the Train Test sets prepared by data_pipeline.ipynb and conducts word2vec modelling
#
# reference: https://www.analyticsvidhya.com/blog/2020/08/information-retrieval-using-word2vec-based-vector-space-model/

# %% [markdown]
# # Load libraries

# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Load Train Test queries and passages

# %%
# query
query_train = pd.read_csv("./output/query_train_set_with_passage_info.csv")
query_test =pd.read_csv("./output/query_test_set_with_passage_info.csv")

# passage
passage_train = pd.read_csv("./output/train_passage_id_content_cleaned.csv")
passage_test = pd.read_csv("./output/test_passage_id_content_cleaned.csv")

# %%
print(query_train.shape)
print(query_test.shape)
print(passage_train.shape)
print(passage_test.shape)
# Out:
# (20000, 9)
# (20000, 9)
# (19898, 4)
# (19893, 4)

# %%
display(query_train.head())
display(query_test.head())
display(passage_train.head())
display(passage_test.head())
# Out:
#    query_id          query used                    passage_id  rank     score  \
# 0    560129  what are hues   Q0  msmarco_passage_03_496902198     1  8.460100
# 1    560129  what are hues   Q0  msmarco_passage_35_561149885     2  8.460099
# 2    560129  what are hues   Q0  msmarco_passage_05_224676265     3  8.176700
# 3    560129  what are hues   Q0  msmarco_passage_04_168335684     4  8.112500
# 4    560129  what are hues   Q0  msmarco_passage_02_769341954     5  8.085500
#
#    username  rel  query_cleaned
# 0  Anserini    1  what are hues
# 1  Anserini    1  what are hues
# 2  Anserini    1  what are hues
# 3  Anserini    1  what are hues
# 4  Anserini    1  what are hues
#    query_id                                              query used  \
# 0    916247  what us state bears the slogan the land enchan...   Q0
# 1    916247  what us state bears the slogan the land enchan...   Q0
# 2    916247  what us state bears the slogan the land enchan...   Q0
# 3    916247  what us state bears the slogan the land enchan...   Q0
# 4    916247  what us state bears the slogan the land enchan...   Q0
#
#                      passage_id  rank      score  username  rel  \
# 0  msmarco_passage_05_840839268     1  16.004101  Anserini    1
# 1  msmarco_passage_06_203354916     2  15.715500  Anserini    1
# 2  msmarco_passage_45_489369159     3  15.715499  Anserini    1
# 3  msmarco_passage_50_676325639     4  14.983700  Anserini    1
# 4  msmarco_passage_21_464076261     5  14.347200  Anserini    1
#
#                                        query_cleaned
# 0  what us state bears the slogan the land enchan...
# 1  what us state bears the slogan the land enchan...
# 2  what us state bears the slogan the land enchan...
# 3  what us state bears the slogan the land enchan...
# 4  what us state bears the slogan the land enchan...
#                      passage_id  \
# 0  msmarco_passage_03_496902198
# 1  msmarco_passage_35_561149885
# 2  msmarco_passage_05_224676265
# 3  msmarco_passage_04_168335684
# 4  msmarco_passage_02_769341954
#
#                                              passage  \
# 0  Let’s dig a little deeper into each. Hues are ...
# 1  Let’s dig a little deeper into each. Hues are ...
# 2  Hue: This is what we usually mean when we ask ...
# 3  hue = color or a shade of color\nexample sente...
# 4  Hue: Hue is what we normally think of as color...
#
#                                      passage_cleaned  \
# 0  let s dig a little deeper into each hues are c...
# 1  let s dig a little deeper into each hues are c...
# 2  hue this is what we usually mean when we ask w...
# 3  hue color or a shade of color example sentence...
# 4  hue hue is what we normally think of as color ...
#
#                           passage_cleaned_lemmatized
# 0  let s dig little deeply hue color hue dependen...
# 1  let s dig little deeply hue color hue dependen...
# 2  hue usually mean ask color property color actu...
# 3  hue color shade color example sentence baby sk...
# 4  hue hue normally think color technically hue d...
#                      passage_id  \
# 0  msmarco_passage_05_840839268
# 1  msmarco_passage_06_203354916
# 2  msmarco_passage_45_489369159
# 3  msmarco_passage_50_676325639
# 4  msmarco_passage_21_464076261
#
#                                              passage  \
# 0  New Mexico State Symbols. State Nickname: The ...
# 1  Land of Enchantment. Before Land of Enchantmen...
# 2  Land of Enchantment. Before Land of Enchantmen...
# 3  New Mexico State Slogans. Whereas the New Mexi...
# 4  1 to approximately 99-000. First use of the "L...
#
#                                      passage_cleaned  \
# 0  new mexico state symbols state nickname the la...
# 1  land of enchantment before land of enchantment...
# 2  land of enchantment before land of enchantment...
# 3  new mexico state slogans whereas the new mexic...
# 4   to approximately first use of the land of enc...
#
#                           passage_cleaned_lemmatized
# 0  new mexico state symbols state nickname land e...
# 1  land enchantment land enchantment state slogan...
# 2  land enchantment land enchantment state slogan...
# 3  new mexico state slogan new mexico state motto...
# 4    approximately use land enchantment slogan em...

# %% [markdown]
# # Train and Test set - combine queries with passage

# %%
query_train["query_cleaned"].head()
# Out:
# 0    what are hues
# 1    what are hues
# 2    what are hues
# 3    what are hues
# 4    what are hues
# Name: query_cleaned, dtype: object

# %%
passage_train["passage_cleaned_lemmatized"].head()
# Out:
# 0    let s dig little deeply hue color hue dependen...
# 1    let s dig little deeply hue color hue dependen...
# 2    hue usually mean ask color property color actu...
# 3    hue color shade color example sentence baby sk...
# 4    hue hue normally think color technically hue d...
# Name: passage_cleaned_lemmatized, dtype: object

# %%
passage_train.rename(columns={"passage_cleaned_lemmatized":"text"}).head()
# Out:
#                      passage_id  \
# 0  msmarco_passage_03_496902198
# 1  msmarco_passage_35_561149885
# 2  msmarco_passage_05_224676265
# 3  msmarco_passage_04_168335684
# 4  msmarco_passage_02_769341954
#
#                                              passage  \
# 0  Let’s dig a little deeper into each. Hues are ...
# 1  Let’s dig a little deeper into each. Hues are ...
# 2  Hue: This is what we usually mean when we ask ...
# 3  hue = color or a shade of color\nexample sente...
# 4  Hue: Hue is what we normally think of as color...
#
#                                      passage_cleaned  \
# 0  let s dig a little deeper into each hues are c...
# 1  let s dig a little deeper into each hues are c...
# 2  hue this is what we usually mean when we ask w...
# 3  hue color or a shade of color example sentence...
# 4  hue hue is what we normally think of as color ...
#
#                                                 text
# 0  let s dig little deeply hue color hue dependen...
# 1  let s dig little deeply hue color hue dependen...
# 2  hue usually mean ask color property color actu...
# 3  hue color shade color example sentence baby sk...
# 4  hue hue normally think color technically hue d...

# %% [markdown]
# ## Remove passage that get null after lemmatization

# %%
passage_train[passage_train["passage_cleaned_lemmatized"].isnull()]
# Out:
#                          passage_id  \
# 10153  msmarco_passage_25_423645543
#
#                                                  passage  \
# 10153  what's your take on that. what's yours. What's...
#
#                                          passage_cleaned  \
# 10153  what is your take on that what is yours what i...
#
#       passage_cleaned_lemmatized
# 10153                        NaN

# %%
passage_test[passage_test["passage_cleaned_lemmatized"].isnull()]
# Out:
#                          passage_id  \
# 10786  msmarco_passage_25_423645543
#
#                                                  passage  \
# 10786  what's your take on that. what's yours. What's...
#
#                                          passage_cleaned  \
# 10786  what is your take on that what is yours what i...
#
#       passage_cleaned_lemmatized
# 10786                        NaN

# %%
passage_train = passage_train[passage_train["passage_id"]!="msmarco_passage_25_423645543"]

# %%
passage_test = passage_test[passage_test["passage_id"]!="msmarco_passage_25_423645543"]

# %%
#query_train = query_train[query_train["passage_id"]!="msmarco_passage_25_423645543"]

# %%
query_train[query_train["query_cleaned"].isnull()]
# Out:
# Empty DataFrame
# Columns: [query_id, query, used, passage_id, rank, score, username, rel, query_cleaned]
# Index: []

# %%
# Combining corpus and queries for training
combined_training = (pd.concat([passage_train.rename(columns={"passage_cleaned_lemmatized":"text"})["text"],
                             query_train.rename(columns={"query_cleaned":'text'})['text']])
                             .sample(frac=1) #shuffle
                             .reset_index(drop=True))
print(passage_train.shape)
print(query_train.shape)
print(combined_training.shape)
display(combined_training.head())
# Out:
# (19897, 4)
# (20000, 9)
# (39897,)
# 0    oklahoma vs texas series history score time ga...
# 1    viral meningitis easily mistaken common flu co...
# 2    wild huckleberry jam learn exquisitely delicio...
# 3    ridgewood ny cover zip code zip code type coun...
# 4                              what is butane found in
# Name: text, dtype: object

# %%
# Creating data for the model training
train_data=[]
for i in combined_training:
    train_data.append(i.split())

# Training a word2vec model from the given data set
w2v_model = Word2Vec(train_data
                     , vector_size = 300
                     , min_count = 2
                     , window = 5
                     , sg = 1
                     , workers = 4)

# %%
# Vocabulary size
print('Vocabulary size:', len(w2v_model.wv))
# Out:
# Vocabulary size: 19605

# %%
# Function returning vector reperesentation of a document
def get_embedding_w2v(doc_tokens):
    embeddings = []
    if len(doc_tokens)<1:
        return np.zeros(300)
    else:
        for tok in doc_tokens:
            if tok in w2v_model.wv:
                embeddings.append(w2v_model.wv.get_vector(tok))
            else:
                embeddings.append(np.random.rand(300))
        # mean the vectors of individual words to get the vector of the document
        return np.mean(embeddings, axis=0)

# %%
"hello" in w2v_model.wv
# Out:
# True

# %%
len(w2v_model.wv.get_vector("hello"))
# Out:
# 300

# %%
# Getting Word2Vec Vectors for Testing Corpus and Queries
passage_test["vector"] = passage_test["passage_cleaned_lemmatized"].apply(lambda x :get_embedding_w2v(x.split()))
query_test["vector"] = query_test["query_cleaned"].apply(lambda x :get_embedding_w2v(x.split()))

# %%
passage_test.head()
# Out:
#                      passage_id  \
# 0  msmarco_passage_05_840839268
# 1  msmarco_passage_06_203354916
# 2  msmarco_passage_45_489369159
# 3  msmarco_passage_50_676325639
# 4  msmarco_passage_21_464076261
#
#                                              passage  \
# 0  New Mexico State Symbols. State Nickname: The ...
# 1  Land of Enchantment. Before Land of Enchantmen...
# 2  Land of Enchantment. Before Land of Enchantmen...
# 3  New Mexico State Slogans. Whereas the New Mexi...
# 4  1 to approximately 99-000. First use of the "L...
#
#                                      passage_cleaned  \
# 0  new mexico state symbols state nickname the la...
# 1  land of enchantment before land of enchantment...
# 2  land of enchantment before land of enchantment...
# 3  new mexico state slogans whereas the new mexic...
# 4   to approximately first use of the land of enc...
#
#                           passage_cleaned_lemmatized  \
# 0  new mexico state symbols state nickname land e...
# 1  land enchantment land enchantment state slogan...
# 2  land enchantment land enchantment state slogan...
# 3  new mexico state slogan new mexico state motto...
# 4    approximately use land enchantment slogan em...
#
#                                               vector
# 0  [0.10714113313825123, 0.1778335256653249, 0.16...
# 1  [0.07339606114876081, 0.18071784250636835, 0.0...
# 2  [0.07796449897246016, 0.17779145835860388, 0.0...
# 3  [0.09267343352251192, 0.2007432824932839, 0.03...
# 4  [0.09051720956927285, 0.19726927596208726, 0.1...

# %%
len(passage_test["vector"][0])
# Out:
# 300

# %%
query_test.head()
# Out:
#    query_id                                              query used  \
# 0    916247  what us state bears the slogan the land enchan...   Q0
# 1    916247  what us state bears the slogan the land enchan...   Q0
# 2    916247  what us state bears the slogan the land enchan...   Q0
# 3    916247  what us state bears the slogan the land enchan...   Q0
# 4    916247  what us state bears the slogan the land enchan...   Q0
#
#                      passage_id  rank      score  username  rel  \
# 0  msmarco_passage_05_840839268     1  16.004101  Anserini    1
# 1  msmarco_passage_06_203354916     2  15.715500  Anserini    1
# 2  msmarco_passage_45_489369159     3  15.715499  Anserini    1
# 3  msmarco_passage_50_676325639     4  14.983700  Anserini    1
# 4  msmarco_passage_21_464076261     5  14.347200  Anserini    1
#
#                                        query_cleaned  \
# 0  what us state bears the slogan the land enchan...
# 1  what us state bears the slogan the land enchan...
# 2  what us state bears the slogan the land enchan...
# 3  what us state bears the slogan the land enchan...
# 4  what us state bears the slogan the land enchan...
#
#                                               vector
# 0  [0.12157598176674626, 0.02919543420329544, 0.0...
# 1  [0.15343830086085708, -0.04190372194763639, -0...
# 2  [0.07225664693710558, -0.061489909499607226, 0...
# 3  [0.11372119184547483, 0.029261907535028973, 0....
# 4  [0.10604383824804584, 0.007542875208101263, 0....

# %%
passage_test.head()
# Out:
#                      passage_id  \
# 0  msmarco_passage_05_840839268
# 1  msmarco_passage_06_203354916
# 2  msmarco_passage_45_489369159
# 3  msmarco_passage_50_676325639
# 4  msmarco_passage_21_464076261
#
#                                              passage  \
# 0  New Mexico State Symbols. State Nickname: The ...
# 1  Land of Enchantment. Before Land of Enchantmen...
# 2  Land of Enchantment. Before Land of Enchantmen...
# 3  New Mexico State Slogans. Whereas the New Mexi...
# 4  1 to approximately 99-000. First use of the "L...
#
#                                      passage_cleaned  \
# 0  new mexico state symbols state nickname the la...
# 1  land of enchantment before land of enchantment...
# 2  land of enchantment before land of enchantment...
# 3  new mexico state slogans whereas the new mexic...
# 4   to approximately first use of the land of enc...
#
#                           passage_cleaned_lemmatized  \
# 0  new mexico state symbols state nickname land e...
# 1  land enchantment land enchantment state slogan...
# 2  land enchantment land enchantment state slogan...
# 3  new mexico state slogan new mexico state motto...
# 4    approximately use land enchantment slogan em...
#
#                                               vector
# 0  [0.10714113313825123, 0.1778335256653249, 0.16...
# 1  [0.07339606114876081, 0.18071784250636835, 0.0...
# 2  [0.07796449897246016, 0.17779145835860388, 0.0...
# 3  [0.09267343352251192, 0.2007432824932839, 0.03...
# 4  [0.09051720956927285, 0.19726927596208726, 0.1...

# %% [markdown]
# ## Test the code - add display, only use 1 query to test

# %%
# Function for calculating average precision for a query
def average_precision(qid, qvector):
    
    # ========= for each query_id, do the following:
    print(f"Started to work on query_id {qid}")
    # get passage_id (each query_id would have upto 10 passage_id)
    qresult = query_test.loc[query_test["query_id"] == qid, ["passage_id", "rel"]]
    # get passage vector for each passage_id
    qcorpus = passage_test.loc[passage_test["passage_id"].isin(qresult["passage_id"]),["passage_id","vector"]]
    
    # inner join passage_id with passage vector
    # this is a result table of <= 10 rows, 2 columns: passage_id and vector
    qresult = pd.merge(qresult, qcorpus, on = "passage_id", how = "inner")

    # create a new column "similarity", 
    # by comparing similarity between the query vector (input qvector) with passage vector (the "vector" column)
    qresult["similarity"] = qresult["vector"].apply(lambda x: cosine_similarity(
                          np.array(qvector).reshape(1, -1)
                          , np.array(x).reshape(1, -1)).item())
    
    # sort rows so that passages with the highest similarity ranks as top 
    qresult.sort_values(by="similarity", ascending = False, inplace=True)

    # # Taking Top 10 documents for the evaluation
    ranking = qresult.head(10)['rel'].values
    display(qresult.head(15))
    
    # # Calculating precision
    precision=[]
    for i in range(1,11):
      if ranking[i-1]:
        precision.append(np.sum(ranking[:i])/i)
    
    # If no relevant document in list then return 0
    if precision==[]:
      return 0
    print(len(precision))
    print(precision)
    avg_precision = np.mean(precision)
    print("Avg precision: {}".format(avg_precision))
    return avg_precision

# %%
query_test.iloc[[0]]
# Out:
#    query_id                                              query used  \
# 0    916247  what us state bears the slogan the land enchan...   Q0
#
#                      passage_id  rank      score  username  rel  \
# 0  msmarco_passage_05_840839268     1  16.004101  Anserini    1
#
#                                        query_cleaned  \
# 0  what us state bears the slogan the land enchan...
#
#                                               vector
# 0  [0.12157598176674626, 0.02919543420329544, 0.0...

# %%
# use one sample to decompose the function
query_test.iloc[[0]].apply(lambda x: average_precision(x['query_id']
                                    , x['vector']),axis=1)
# Out:
# Started to work on query_id 916247
#                       passage_id  rel  \
# 10   msmarco_passage_06_45103616    0
# 17  msmarco_passage_31_763502859    0
# 16  msmarco_passage_32_313105536    0
# 9   msmarco_passage_00_583662759    1
# 18  msmarco_passage_59_350363899    0
# 14  msmarco_passage_21_306563782    0
# 7   msmarco_passage_32_845400104    1
# 6   msmarco_passage_09_683772331    1
# 5   msmarco_passage_50_676326055    1
# 3   msmarco_passage_50_676325639    1
# 2   msmarco_passage_45_489369159    1
# 1   msmarco_passage_06_203354916    1
# 8   msmarco_passage_22_677091138    1
# 0   msmarco_passage_05_840839268    1
# 11  msmarco_passage_04_268326037    0
#
#                                                vector  similarity
# 10  [0.010186836311570543, 0.17875827009067263, 0....    0.705933
# 17  [0.02013530526808486, 0.12320358506001251, 0.0...    0.679798
# 16  [-0.03648880997595349, 0.16510888637001117, 0....    0.670987
# 9   [0.07698440788327167, 0.21884311187699476, 0.1...    0.667068
# 18  [0.10438256711406776, 0.24298040882433303, -0....    0.664028
# 14  [0.12585165567532555, 0.1781596062872793, 0.07...    0.659044
# 7   [0.1216687708723149, 0.18722428885586404, 0.03...    0.655139
# 6   [0.14146233821608756, 0.2070966387719616, 0.01...    0.653068
# 5   [0.16858622793763356, 0.21915998827313496, 0.1...    0.648961
# 3   [0.09267343352251192, 0.2007432824932839, 0.03...    0.643174
# 2   [0.07796449897246016, 0.17779145835860388, 0.0...    0.641288
# 1   [0.07339606114876081, 0.18071784250636835, 0.0...    0.639886
# 8   [-0.03247817652570527, 0.18173048184249976, -0...    0.639772
# 0   [0.10714113313825123, 0.1778335256653249, 0.16...    0.634441
# 11  [0.03715102393495367, 0.1663151431969628, -0.0...    0.595466
# 5
# [0.25, 0.2857142857142857, 0.375, 0.4444444444444444, 0.5]
# Avg precision: 0.37103174603174605
# 0    0.371032
# dtype: float64

# %% [markdown]
# ## Run the code of average_precision - do not display, run on all query_id

# %%
# Function for calculating average precision for a query
def average_precision(qid, qvector):   
    # ========= for each query_id, do the following:
    print(f"\nStarted to work on query_id {qid}")
    # get passage_id (each query_id would have upto 10 passage_id)
    qresult = query_test.loc[query_test["query_id"] == qid, ["passage_id", "rel"]]
    # get passage vector for each passage_id
    qcorpus = passage_test.loc[passage_test["passage_id"].isin(qresult["passage_id"]),["passage_id","vector"]]
    
    # inner join passage_id with passage vector
    # this is a result table of <= 10 rows, 2 columns: passage_id and vector
    qresult = pd.merge(qresult, qcorpus, on = "passage_id", how = "inner")

    # create a new column "similarity", 
    # by comparing similarity between the query vector (input qvector) with passage vector (the "vector" column)
    qresult["similarity"] = qresult["vector"].apply(lambda x: cosine_similarity(
                          np.array(qvector).reshape(1, -1)
                          , np.array(x).reshape(1, -1)).item())
    
    # sort rows so that passages with the highest similarity ranks as top 
    qresult.sort_values(by="similarity", ascending = False, inplace=True)

    # # Taking Top 10 documents for the evaluation
    ranking = qresult.head(10)['rel'].values
    #display(qresult.head(15))
    
    # # Calculating precision
    precision=[]
    for i in range(1,11):
      if ranking[i-1]:
        precision.append(np.sum(ranking[:i])/i)
    
    # If no relevant document in list then return 0
    if precision==[]:
      return 0
    print(len(precision))
    #print(precision)
    avg_precision = np.mean(precision)
    print("Avg precision: {}".format(avg_precision))
    return avg_precision

# %%
# Calculating average precision for all queries in the test set
query_test["avg_precision"] = query_test.apply(lambda x: average_precision(x["query_id"]
                                                                           ,x["vector"]),axis=1)
# Out:
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.3876984126984127
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.36103174603174604
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.36103174603174604
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.3876984126984127
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.36103174603174604
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.40793650793650793
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.36103174603174604
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.36103174603174604
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.3705555555555556
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.38055555555555554
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 916247
# 5
# Avg precision: 0.37103174603174605
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.5783333333333334
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.7544444444444445
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.7683333333333333
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6683333333333333
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6683333333333333
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.7166666666666666
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6683333333333333
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.5783333333333334
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6416666666666666
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6783333333333333
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.7544444444444445
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.7277777777777776
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6277777777777777
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.7683333333333333
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 203324
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.69375
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.69375
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.54375
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.69375
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.56875
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.56875
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6104166666666666
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6104166666666666
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6104166666666666
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.69375
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6104166666666666
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6215277777777777
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.725
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.7071428571428571
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.56875
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 54169
# 4
# Avg precision: 0.6777777777777778
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8857142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8857142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8634920634920635
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8968253968253969
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.8857142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 766010
# 6
# Avg precision: 0.9107142857142857
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.7892857142857143
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.5944444444444444
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.4523809523809524
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.6444444444444445
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.6644444444444444
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.5768253968253967
#
# Started to work on query_id 497475
# 6
# Avg precision: 0.707936507936508
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.4411111111111111
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.525952380952381
#
# Started to work on query_id 497475
# 6
# Avg precision: 0.762037037037037
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.6333333333333333
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.5676190476190476
#
# Started to work on query_id 497475
# 6
# Avg precision: 0.6537037037037037
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.6342857142857143
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.5476190476190477
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.44388888888888883
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.5926190476190476
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.8111111111111111
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.7311111111111112
#
# Started to work on query_id 497475
# 5
# Avg precision: 0.5192857142857144
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.20833333333333331
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 3
# Avg precision: 0.23095238095238094
#
# Started to work on query_id 859307
# 3
# Avg precision: 0.23095238095238094
#
# Started to work on query_id 859307
# 3
# Avg precision: 0.23095238095238094
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 3
# Avg precision: 0.23095238095238094
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.19642857142857142
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.20833333333333331
#
# Started to work on query_id 859307
# 3
# Avg precision: 0.23888888888888885
#
# Started to work on query_id 859307
# 2
# Avg precision: 0.18253968253968253
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.5199999999999999
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.512063492063492
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.5009523809523809
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.5199999999999999
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.4920634920634921
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.512063492063492
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.5199999999999999
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.4609523809523809
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.5009523809523809
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.531111111111111
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.5199999999999999
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.48666666666666664
#
# Started to work on query_id 666017
# 5
# Avg precision: 0.512063492063492
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 175907
# 6
# Avg precision: 0.6806878306878307
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.7749999999999999
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6569444444444444
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.7749999999999999
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.7749999999999999
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.7551587301587301
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6916666666666668
#
# Started to work on query_id 422112
# 6
# Avg precision: 0.6718253968253968
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 975972
# 4
# Avg precision: 0.6458333333333333
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.85
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.8611111111111112
#
# Started to work on query_id 73785
# 3
# Avg precision: 1.0
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.85
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.875
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.875
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.875
#
# Started to work on query_id 73785
# 3
# Avg precision: 1.0
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.8611111111111112
#
# Started to work on query_id 73785
# 3
# Avg precision: 1.0
#
# Started to work on query_id 73785
# 3
# Avg precision: 1.0
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.85
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.8928571428571428
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.85
#
# Started to work on query_id 73785
# 3
# Avg precision: 1.0
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.85
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.8611111111111112
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.85
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.8611111111111112
#
# Started to work on query_id 73785
# 4
# Avg precision: 0.875
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.7947278911564626
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.8634920634920635
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.8486111111111111
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.7947278911564626
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.7440476190476191
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.725
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.7726190476190476
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.8551587301587301
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.8152777777777777
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.725
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.8486111111111111
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.8210884353741497
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.725
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.7847222222222222
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.7847222222222222
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.810515873015873
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.7688492063492064
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.7377551020408164
#
# Started to work on query_id 926933
# 7
# Avg precision: 0.7440476190476192
#
# Started to work on query_id 926933
# 6
# Avg precision: 0.7736111111111109
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 959660
# 5
# Avg precision: 0.41571428571428565
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 732623
# 4
# Avg precision: 0.586111111111111
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 783031
# 5
# Avg precision: 0.5305555555555556
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 90403
# 9
# Avg precision: 0.7856701940035273
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 983405
# 4
# Avg precision: 0.39464285714285713
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7662698412698413
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.8416666666666667
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.6930555555555555
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7662698412698413
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7291666666666666
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7021825396825396
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.8218253968253969
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7861111111111111
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7132936507936508
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.660515873015873
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7996031746031745
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7180555555555554
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7180555555555554
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7021825396825396
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.6489417989417989
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7041666666666666
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7402777777777777
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.6930555555555555
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.7291666666666666
#
# Started to work on query_id 897444
# 6
# Avg precision: 0.6771825396825396
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 812120
# 3
# Avg precision: 0.35000000000000003
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 508287
# 7
# Avg precision: 0.855952380952381
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 565754
# 6
# Avg precision: 0.594047619047619
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 808995
# 6
# Avg precision: 0.7345238095238096
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 4
# Avg precision: 0.5249999999999999
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 4
# Avg precision: 0.5249999999999999
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 4
# Avg precision: 0.5249999999999999
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 1182015
# 3
# Avg precision: 0.4777777777777777
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 41650
# 5
# Avg precision: 0.7961904761904762
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 707275
# 5
# Avg precision: 0.6116666666666666
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7064814814814814
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7861111111111111
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.75
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.7611111111111111
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7878306878306877
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7342592592592592
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7759259259259258
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.6814814814814815
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.6944444444444444
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.6814814814814815
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.8444444444444444
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.6787037037037037
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7342592592592592
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7329365079365079
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.7087301587301587
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.7759259259259258
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.7644444444444444
#
# Started to work on query_id 493107
# 6
# Avg precision: 0.8037037037037037
#
# Started to work on query_id 493107
# 5
# Avg precision: 0.8
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 943857
# 7
# Avg precision: 0.961734693877551
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 281376
# 6
# Avg precision: 0.5267195767195767
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 393024
# 6
# Avg precision: 0.7438492063492065
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.42658730158730157
#
# Started to work on query_id 1069649
# 5
# Avg precision: 0.4523809523809524
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.41547619047619044
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.4012896825396825
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.41874999999999996
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.40208333333333335
#
# Started to work on query_id 1069649
# 5
# Avg precision: 0.45460317460317456
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.3604166666666666
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.3738095238095238
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.40208333333333335
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.41547619047619044
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.34851190476190474
#
# Started to work on query_id 1069649
# 3
# Avg precision: 0.40277777777777773
#
# Started to work on query_id 1069649
# 3
# Avg precision: 0.5535714285714285
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.42658730158730157
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.37152777777777773
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.41547619047619044
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.41874999999999996
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.34851190476190474
#
# Started to work on query_id 1069649
# 4
# Avg precision: 0.4611111111111111
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 597921
# 6
# Avg precision: 0.5021825396825397
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4556878306878307
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4556878306878307
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4556878306878307
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4556878306878307
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4556878306878307
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 155440
# 6
# Avg precision: 0.4695767195767196
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5694444444444444
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5916666666666667
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5694444444444444
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5694444444444444
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5916666666666667
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.6095238095238095
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5777777777777777
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5916666666666667
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.40277777777777773
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5694444444444444
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.42063492063492064
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5694444444444444
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.5694444444444444
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 731051
# 3
# Avg precision: 0.425
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9467813051146384
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9467813051146384
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9282627865961199
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9765432098765433
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9626543209876544
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9765432098765433
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9467813051146384
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9888888888888889
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9626543209876544
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9626543209876544
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9467813051146384
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9467813051146384
#
# Started to work on query_id 792794
# 9
# Avg precision: 0.9888888888888889
#
# Started to work on query_id 792794
# ...
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 460806
# 6
# Avg precision: 0.5703703703703703
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 311282
# 5
# Avg precision: 0.9
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.7044217687074831
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6797619047619048
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.666156462585034
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6797619047619048
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6518707482993197
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6518707482993197
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.666156462585034
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6797619047619048
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.7155328798185941
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6797619047619048
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.7044217687074831
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.6925170068027212
#
# Started to work on query_id 606611
# 7
# Avg precision: 0.7044217687074831
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.45846560846560847
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.45846560846560847
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.43624338624338627
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.45846560846560847
#
# Started to work on query_id 1028406
# 5
# Avg precision: 0.41349206349206347
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.4862433862433862
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.43624338624338627
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.4862433862433862
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.45846560846560847
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.43624338624338627
#
# Started to work on query_id 1028406
# 5
# Avg precision: 0.41349206349206347
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.44457671957671957
#
# Started to work on query_id 1028406
# 6
# Avg precision: 0.45846560846560847
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 875084
# 3
# Avg precision: 0.6
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.5
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.6
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.6
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.48666666666666664
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.48666666666666664
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.5
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.5009523809523809
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.5009523809523809
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.5009523809523809
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.6333333333333333
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.6
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.52
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.6342857142857143
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.4666666666666666
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.48666666666666664
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.62
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.4666666666666666
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.72
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.6
#
# Started to work on query_id 748959
# 5
# Avg precision: 0.4666666666666666
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 723184
# 5
# Avg precision: 0.6544444444444444
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2216931216931217
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.24206349206349206
#
# Started to work on query_id 911782
# 4
# Avg precision: 0.5595238095238095
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.25
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2216931216931217
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2507936507936508
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.3833333333333333
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.25
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.27777777777777773
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2157407407407407
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2216931216931217
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.27777777777777773
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2507936507936508
#
# Started to work on query_id 911782
# 3
# Avg precision: 0.2216931216931217
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 604341
# 6
# Avg precision: 0.9761904761904762
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 230312
# 8
# Avg precision: 0.7713789682539682
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 357960
# 4
# Avg precision: 0.6833333333333333
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0
#
# Started to work on query_id 587035
# 4
# Avg precision: 1.0

# %%
query_test.head()
# Out:
#    query_id                                              query used  \
# 0    916247  what us state bears the slogan the land enchan...   Q0
# 1    916247  what us state bears the slogan the land enchan...   Q0
# 2    916247  what us state bears the slogan the land enchan...   Q0
# 3    916247  what us state bears the slogan the land enchan...   Q0
# 4    916247  what us state bears the slogan the land enchan...   Q0
#
#                      passage_id  rank      score  username  rel  \
# 0  msmarco_passage_05_840839268     1  16.004101  Anserini    1
# 1  msmarco_passage_06_203354916     2  15.715500  Anserini    1
# 2  msmarco_passage_45_489369159     3  15.715499  Anserini    1
# 3  msmarco_passage_50_676325639     4  14.983700  Anserini    1
# 4  msmarco_passage_21_464076261     5  14.347200  Anserini    1
#
#                                        query_cleaned  \
# 0  what us state bears the slogan the land enchan...
# 1  what us state bears the slogan the land enchan...
# 2  what us state bears the slogan the land enchan...
# 3  what us state bears the slogan the land enchan...
# 4  what us state bears the slogan the land enchan...
#
#                                               vector  avg_precision
# 0  [0.12157598176674626, 0.02919543420329544, 0.0...       0.371032
# 1  [0.15343830086085708, -0.04190372194763639, -0...       0.371032
# 2  [0.07225664693710558, -0.061489909499607226, 0...       0.387698
# 3  [0.11372119184547483, 0.029261907535028973, 0....       0.371032
# 4  [0.10604383824804584, 0.007542875208101263, 0....       0.371032

# %%
# Finding Mean Average Precision
print('Mean Average Precision=>', query_test["avg_precision"].mean())
# Out:
# Mean Average Precision=> 0.6831747470789241
